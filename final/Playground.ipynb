# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import modelBuilder as mb
import main

df = pd.read_csv('data.csv')
df.Time = pd.to_datetime(df.Time)  # change time to datetime object
data = df.drop(['Sourcehash'],axis=1)  # drop unneeded hash

dayda = df.loc[(df.Topic == "lsn6_math") & (df.Stud_ID == "dee9256848fdca4942f5f3243ace75be0f7f64c9")]
qData = mb.convertSQLtoClean(dayda)
problem, questionDifficulty, distributions = main.initialize()
# Out:
# C:\Users\C22Evan.Marrone\Anaconda3\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
distributions
# Out:
#              incorrectLower  hintLower  durationLower  incorrectUpper  \
# problem_id
# CAESAR             1.000000   0.000000       0.000000        1.000000
# Caesar_gc          1.000000   0.000000       0.000000        1.000000
# Lsn5_skill1        2.000000   0.000000       1.366667        2.000000
# Lsn7_lists         8.000000   2.000000      23.033333        8.000000
# PEX1               0.795876  12.708597      37.655661        1.408248
# ...                     ...        ...            ...             ...
# pex2               1.706114   0.000000      13.559933        2.985732
# pex2_gc            2.390562   0.000000      18.511964        4.523960
# pex3               8.355244   0.000000      55.035533       13.726760
# skywriter          1.000000   0.000000       0.000000        1.000000
# to_the_end         3.125000   8.375000      60.000000        4.250000
#
#              hintUpper  durationUpper
# problem_id
# CAESAR        0.000000       0.000000
# ...

# %%
mb.nextQuestion("lsn6_math", questionDifficulty, distributions, qData)
# Out:
# 'lsn6_math'

# %%
questionDifficulty.loc[questionDifficulty.problem_id == 'lsn19_golf']
# Out:
#      problem_id  difficulty
# 379  lsn19_golf    0.484323

# %%
dayda = df.loc[(df.Topic == "lsn13_dvc") & (df.Stud_ID == "a82a958c2ba7a1e17f95665f9af54bef5e1458ac")]
# qData = mb.convertSQLtoClean(dayda)
dayda.iloc[0,4] = 5
dayda
dayda.loc[len(dayda.index)] = ["a82a958c2ba7a1e17f95665f9af54bef5e1458ac","lsn13_dvc","2021-01-24 02:25:25","1","0.0","55ba1af7d87fe39e5556a72bb9af16bacb632c72"]
# Out:
# C:\Users\C22Evan.Marrone\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\C22Evan.Marrone\Anaconda3\lib\site-packages\pandas\core\indexing.py:692: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
mb.nextQuestion('lsn13_dvc', questionDifficulty, distributions, qData)
# Out:
# 'PEX1'

# %%
df.loc[(df.Topic == "lsn13_dvc")]
# Out:
#                                          Stud_ID      Topic  \
# 1586    f6d51c43033d655dafd23f25c86961147cb81ed8  lsn13_dvc
# 22941   a82a958c2ba7a1e17f95665f9af54bef5e1458ac  lsn13_dvc
# 22943   a82a958c2ba7a1e17f95665f9af54bef5e1458ac  lsn13_dvc
# 22946   a82a958c2ba7a1e17f95665f9af54bef5e1458ac  lsn13_dvc
# 22947   a82a958c2ba7a1e17f95665f9af54bef5e1458ac  lsn13_dvc
# ...                                          ...        ...
# 651912  2d2cd262be403b6803e75e2182da622f1f3e3310  lsn13_dvc
# 651960  2d2cd262be403b6803e75e2182da622f1f3e3310  lsn13_dvc
# 651987  2d2cd262be403b6803e75e2182da622f1f3e3310  lsn13_dvc
# 651992  2d2cd262be403b6803e75e2182da622f1f3e3310  lsn13_dvc
# 651994  2d2cd262be403b6803e75e2182da622f1f3e3310  lsn13_dvc
#
#                       Time  Graded  Score  \
# 1586   2021-01-14 06:52:33       1  100.0
# 22941  2021-01-24 02:25:25       1    0.0
# 22943  2021-01-24 02:25:59       1    0.0
# 22946  2021-01-24 02:26:40       1    0.0
# ...

# %%
distributions = mb.distributionBuilder(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-8cee9b161ec8> in <module>
# ----> 1 distributions = mb.distributionBuilder(data)
#
# ~\OneDrive - afacademy.af.edu\Desktop\Classes\Capstone\Sprint 6\modelBuilder.py in distributionBuilder(df)
#     115     # group the problems and students together to get the sum of each variable for each question
#     116     problemDistsLower = df.groupby(["Topic"]).agg(chi2lower)  # creates the lower bound dists
# --> 117     problemDistsUpper = df.groupby(["Topic"]).agg(chi2upper)  # creates the upper bound dists
#     118
#     119     # rename columns so we can combine the upper and lower distributions
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# ...

# %%
data
# Out:
#                                          Stud_ID            Topic  \
# 0       04b124817f36bfdc7cffbe17e0a52d5f8c5eaa38  lsn1_helloworld
# 1       04b124817f36bfdc7cffbe17e0a52d5f8c5eaa38  lsn1_helloworld
# 2       04b124817f36bfdc7cffbe17e0a52d5f8c5eaa38  lsn1_helloworld
# 3       04b124817f36bfdc7cffbe17e0a52d5f8c5eaa38  lsn1_helloworld
# 4       04b124817f36bfdc7cffbe17e0a52d5f8c5eaa38  lsn1_helloworld
# ...                                          ...              ...
# 666217  58fbeebcdf02f3ccbac0859f5da7662d9a9653d9  lsn24_education
# 666218  9bbd681147a96dc72cf672b9bfa105ee6add3792            Recon
# 666219  427ece0b0a05cb848051107f7468faf2aae862ce  lsn24_education
# 666220  58fbeebcdf02f3ccbac0859f5da7662d9a9653d9  lsn24_education
# 666221  427ece0b0a05cb848051107f7468faf2aae862ce  lsn24_education
#
#                       Time  Graded  Score
# 0      2020-12-31 21:30:52       1  100.0
# 1      2020-12-31 21:31:00       1  100.0
# 2      2020-12-31 21:34:47       1  100.0
# ...

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import modelBuilder as mb
import main

data = mb.importData()
distributions = mb.distributionBuilder(data)

# %%
data
# Out:
#                                          stud_id      problem_id  incorrect  \
# 0       006b60bea73767757ed3907453abffb2825ff86b       Skywriter          1
# 1       006b60bea73767757ed3907453abffb2825ff86b   a1_1_aircraft          0
# 2       006b60bea73767757ed3907453abffb2825ff86b    a1_2_circles          1
# 3       006b60bea73767757ed3907453abffb2825ff86b      a1_3_cards          0
# 4       006b60bea73767757ed3907453abffb2825ff86b   a1_4_sickness          0
# ...                                          ...             ...        ...
# 127116  ff8cadc383e74c88c5da48a2a37df29770f54143  lsn9_practice2         10
# 127117  ff8cadc383e74c88c5da48a2a37df29770f54143  lsn9_practice3          3
# 127118  ff8cadc383e74c88c5da48a2a37df29770f54143  lsn9_practice4          1
# 127119  ff8cadc383e74c88c5da48a2a37df29770f54143            pex1          2
# 127120  ff8cadc383e74c88c5da48a2a37df29770f54143            pex3         16
#
#         hint   duration
# 0          0   0.000000
# ...

# %%
pd.DataFrame()
